# %% [markdown]
# ![visioncolab](https://drive.google.com/uc?export=view&id=10UMKqKSnU2grmitxYxvL7V6GVMu8RrpP)
#
#
# `Google colab's for image processing, pattern recognition and computer vision`
#
# [Domingo Mery](https://domingomery.ing.puc.cl/) - Department of Computer Science - Universidad Católica de Chile

# %% [markdown]
# # Basic Image Restoration

# %% [markdown]
# # Original Images used in this Example:
#
#
# 1.   Santiago: https://flic.kr/p/VD2Pin
# 2.   Door: https://flic.kr/p/dmx5iU
#
#
# (c) Domingo Mery

# %%
# !wget https://www.dropbox.com/s/w9tew0pn2259kgl/santiago.png
# !wget https://www.dropbox.com/s/i62imnk7j0ot430/puerta_bw.png
# !wget https://www.dropbox.com/s/z0bkrak7n5n19qg/santiago512.png
# Out:
# --2025-10-14 12:23:43--  https://www.dropbox.com/s/w9tew0pn2259kgl/santiago.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/5zkmyirx6caw4d1xip6tn/santiago.png?rlkey=hi1qlcea3s9gyk0ynuc5g2jen [following]
# --2025-10-14 12:23:43--  https://www.dropbox.com/scl/fi/5zkmyirx6caw4d1xip6tn/santiago.png?rlkey=hi1qlcea3s9gyk0ynuc5g2jen
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc8de7a766fda7999bff5408022c.dl.dropboxusercontent.com/cd/0/inline/CzPzdQz9bfKw6vhCEC0--D1n1tXXd8JK9FVzi7rVnToErdSJOlaHMtGEkTjqeAAf2HNlSz3X1AevFmjjtM31WTI5c7Jr5fW8rRMvYX7djtucxTogfVAyhDfL2y-50NdwZUg/file# [following]
# --2025-10-14 12:23:44--  https://uc8de7a766fda7999bff5408022c.dl.dropboxusercontent.com/cd/0/inline/CzPzdQz9bfKw6vhCEC0--D1n1tXXd8JK9FVzi7rVnToErdSJOlaHMtGEkTjqeAAf2HNlSz3X1AevFmjjtM31WTI5c7Jr5fW8rRMvYX7djtucxTogfVAyhDfL2y-50NdwZUg/file
# Resolving uc8de7a766fda7999bff5408022c.dl.dropboxusercontent.com (uc8de7a766fda7999bff5408022c.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uc8de7a766fda7999bff5408022c.dl.dropboxusercontent.com (uc8de7a766fda7999bff5408022c.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 639161 (624K) [image/png]
# Saving to: ‘santiago.png’
#
# santiago.png        100%[===================>] 624.18K  --.-KB/s    in 0.09s
#
# 2025-10-14 12:23:44 (6.58 MB/s) - ‘santiago.png’ saved [639161/639161]
#
# --2025-10-14 12:23:44--  https://www.dropbox.com/s/i62imnk7j0ot430/puerta_bw.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/3j13x1k8tl87wzt9eambb/puerta_bw.png?rlkey=ebadesslczeszeixklsxeaxko [following]
# --2025-10-14 12:23:44--  https://www.dropbox.com/scl/fi/3j13x1k8tl87wzt9eambb/puerta_bw.png?rlkey=ebadesslczeszeixklsxeaxko
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uccc467fb1e51a5525c8982cef01.dl.dropboxusercontent.com/cd/0/inline/CzNS2G9JsgEPe767Gnzqwk48aixcrw3WI1A7zbb_NCbeHcB-I-9BAEadEUCN_31YdLkK1MQSrC97OxuLlrPSegvlrO98X-jlrNd-flLrpUDGYKrjlL5W48cokj0VZM8bsxE/file# [following]
# --2025-10-14 12:23:45--  https://uccc467fb1e51a5525c8982cef01.dl.dropboxusercontent.com/cd/0/inline/CzNS2G9JsgEPe767Gnzqwk48aixcrw3WI1A7zbb_NCbeHcB-I-9BAEadEUCN_31YdLkK1MQSrC97OxuLlrPSegvlrO98X-jlrNd-flLrpUDGYKrjlL5W48cokj0VZM8bsxE/file
# Resolving uccc467fb1e51a5525c8982cef01.dl.dropboxusercontent.com (uccc467fb1e51a5525c8982cef01.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uccc467fb1e51a5525c8982cef01.dl.dropboxusercontent.com (uccc467fb1e51a5525c8982cef01.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 241446 (236K) [image/png]
# Saving to: ‘puerta_bw.png’
#
# puerta_bw.png       100%[===================>] 235.79K  --.-KB/s    in 0.06s
#
# 2025-10-14 12:23:45 (3.56 MB/s) - ‘puerta_bw.png’ saved [241446/241446]
#
# --2025-10-14 12:23:45--  https://www.dropbox.com/s/z0bkrak7n5n19qg/santiago512.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/l5axr6i43s7e51o7g9hf9/santiago512.png?rlkey=dlgnct7jm33yx20dztyqbh736 [following]
# --2025-10-14 12:23:46--  https://www.dropbox.com/scl/fi/l5axr6i43s7e51o7g9hf9/santiago512.png?rlkey=dlgnct7jm33yx20dztyqbh736
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc4c897d067e3e98746a1ffbad41.dl.dropboxusercontent.com/cd/0/inline/CzN6p31fvDa3Hf-WgrUdFG2LNsIMtSdGgE2UfyVdHs4RzU-BMGGR3soLnFo0SGV2E__2WlFVF5PZ3wfy621TAnl7OHjFrx3Y9YXLrTGq38FT5B7_vQnGxiYF_drJZP7t9y4/file# [following]
# --2025-10-14 12:23:46--  https://uc4c897d067e3e98746a1ffbad41.dl.dropboxusercontent.com/cd/0/inline/CzN6p31fvDa3Hf-WgrUdFG2LNsIMtSdGgE2UfyVdHs4RzU-BMGGR3soLnFo0SGV2E__2WlFVF5PZ3wfy621TAnl7OHjFrx3Y9YXLrTGq38FT5B7_vQnGxiYF_drJZP7t9y4/file
# Resolving uc4c897d067e3e98746a1ffbad41.dl.dropboxusercontent.com (uc4c897d067e3e98746a1ffbad41.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uc4c897d067e3e98746a1ffbad41.dl.dropboxusercontent.com (uc4c897d067e3e98746a1ffbad41.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 156294 (153K) [image/png]
# Saving to: ‘santiago512.png’
#
# santiago512.png     100%[===================>] 152.63K  --.-KB/s    in 0.05s
#
# 2025-10-14 12:23:46 (2.77 MB/s) - ‘santiago512.png’ saved [156294/156294]

# %% [markdown]
# # Simulation of uniform horizontal motion
#
# In this example:
#
#
#
# * $\bf F$: Original image
# * $\bf G$: Degraded image
# * $\bf \hat F$: Restored image
#
# The degradation process consists of a horizontal uniform motion of $n$ pixels, where each row is modeled as:
# $
# \left[ \begin{array}{c c c c c c c}
# h_1 & ... & h_n & 0   & 0   & 0   & 0   \\
# 0   & h_1 & ... & h_n & 0   & 0   & 0   \\
#     &  :  &     &     & :   &     &     \\
# 0   &  0  &  ...& 0 & h_1 & ... & h_n
# \end{array} \right]
# \left[ \begin{array}{c}
# f_1 \\
# f_2 \\
# :   \\
# f_M
# \end{array}
# \right]
# =
# \left[ \begin{array}{c}
# g_1 \\
# g_2 \\
# :   \\
# g_N
# \end{array}
# \right]
# $

# %%
import numpy as np
import matplotlib.pylab as plt
from cv2 import imread, filter2D, IMREAD_GRAYSCALE, CV_64F

# img = imread('santiago512.png', IMREAD_GRAYSCALE)
#img = imread('santiago.png', IMREAD_GRAYSCALE)
img = imread('puerta_bw.png', IMREAD_GRAYSCALE)

n = 120
h = np.ones((1, n)) / n

N = img.shape[1]
M = N-n+1

img_g = filter2D(img.astype('double'), CV_64F, h)
img_g = img_g[:,0:M]

fig, ax = plt.subplots(2, 1, figsize=(36, 20))
ax[0].imshow(img, cmap='gray')
ax[0].set_title('Original image')
ax[0].axis('on')
ax[1].imshow(img_g, cmap='gray')
ax[1].set_title('Degraded image')
ax[1].axis('on')
plt.show()

# %% [markdown]
# # Restoration algorithm
#
# The solution to this problem is obtained by minimizing the following objective function using Lagrange multipliers:
#
# $
# V({\bf f}) = \lambda\parallel{\bf H}{\bf f}-{\bf g}\parallel^2 +\parallel{\bf  W}{\bf  f}\parallel^2
# $
#
# where $\bf W$ is a regulator that reduces the ripple of ${\bf f}$. Deriving $V$ with respect to ${\bf f}$ and equaling zero we obtain:
#
#
# $
# {\bf \hat f} = \lambda \left[ \lambda {\bf H}^{\sf T} {\bf H} + {\bf W}^{\sf T} {\bf W} \right]^{-1} {\bf H} ^{\sf T} {\bf g}.
# $
#
# In this example, we use ${\bf W} = {\bf I}$, however, other regularization matrices can be used. In practice $10^{6}$ yields good results.

# %% [markdown]
# For MINIO criterium:
#
# Mery, D.; Pieringer C. (2020): Computer Vision for X-ray Testing. Springer. 2nd Edition.

# %% [markdown]
# ![Screen Shot 2020-10-27 at 2.35.30 pm.png](data:image/png;base64,...)

# %%
def res_minio(_img_g, h, method='minio'):
    """

    Args:
        _img_g: blured image as ndarray.
        h: PSF as ndarray.
        method: integer value to select minimization method:
                'minio': ||f_n - g|| -> min
                'other': ||f|| -> min

    Returns:
        _img_f: the restored image as ndarray.

    Raises:
        ValueError: if h is not ndarray.
        Exception

    Authors:
        Christian Pieringer & Domingo Mery
        from pyxvis library.
    """

    _valid_methods = ['minio', 'eye']

    # Check input parameters
    # Input image _img_g
    if not isinstance(_img_g, np.ndarray):
        raise Exception('{} is not valid input format for the blured image _img_g.'.format(type(_img_g)))

    # PSF h
    if not isinstance(h, np.ndarray):
        raise Exception('{} is not a valid format for PSF.'.format(type(h)))

    # Method
    if method not in _valid_methods:
        raise ValueError('method do not meet {} as a valid method'.format(method))

    # Main
    nh = h.shape[-1]
    n = _img_g.shape[-1]
    m = n + nh - 1
    _mat_h = np.zeros((n, m))

    # Composing H matrix
    for i in range(n):
        _mat_h[i, i:i + nh] = h.ravel()

    _lambda = 1e6  # Lagrange multiplier

    if method == 'minio':
        _mat_p = np.hstack([np.eye(n, dtype='float'), np.zeros((n, nh - 1))])
        _img_f = _img_g @ (_lambda * _mat_h + _mat_p)
        _img_f = _img_f @ (np.linalg.inv((_lambda * _mat_h).T @ _mat_h + _mat_p.T @ _mat_p)).T

    if method =='eye':
        _img_f = _img_g @ _mat_h
        _img_f = _img_f @ (np.linalg.inv((_lambda * _mat_h).T @ _mat_h + np.eye(m, dtype='float'))).T

    # Clip the image between 0 and 255
    _img_f[_img_f < 0] = 0
    _img_f[_img_f > 255] = 255

    return _img_f

# %% [markdown]
# # Restoration of horizontal motion blurriness

# %%
import numpy as np
import matplotlib.pylab as plt
from cv2 import imread, filter2D, IMREAD_GRAYSCALE, CV_64F

#img = imread('santiago512.png', IMREAD_GRAYSCALE)
img = imread('santiago.png', IMREAD_GRAYSCALE)
#img = imread('puerta_bw.png', IMREAD_GRAYSCALE)

# Definition of h
n = 250
h = np.ones((1, n)) / n

N = img.shape[1]
M = N-n+1

# Degraded Image
img_g = filter2D(img.astype('double'), CV_64F, h)
img_g = img_g[:,0:M]

# Restoration
fs = res_minio(img_g, h, method='minio')

fig, ax = plt.subplots(3, 1, figsize=(48, 34))
ax[0].imshow(img, cmap='gray')
ax[0].set_title('Original image')
ax[0].axis('on')
ax[1].imshow(img_g, cmap='gray')
ax[1].set_title('Degraded image')
ax[1].axis('on')
ax[2].imshow(fs, cmap='gray')
ax[2].set_title('Restored image')
ax[2].axis('on')
plt.show()
