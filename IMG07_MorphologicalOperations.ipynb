# %% [markdown]
# ![visioncolab](https://drive.google.com/uc?export=view&id=10UMKqKSnU2grmitxYxvL7V6GVMu8RrpP)
#
#
# `Google colab's for image processing, pattern recognition and computer vision`
#
# [Domingo Mery](https://domingomery.ing.puc.cl/) - Department of Computer Science - Universidad Católica de Chile

# %% [markdown]
# # Morphological Operations in Image Porcessing

# %% [markdown]
# From [Tutorial OpenCV](https://opencv24-python-tutorials.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_morphological_ops/py_morphological_ops.html)
#
# This code is based on opencv, also these morphological operations can be found in the library [scikit-image](https://scikit-image.org/docs/dev/api/skimage.morphology.html).

# %% [markdown]
# # Morphological Operations in Binary Images

# %%
# !wget https://www.dropbox.com/s/fok3q35hm1o2k13/jota.png
# Out:
# --2025-10-30 13:41:08--  https://www.dropbox.com/s/fok3q35hm1o2k13/jota.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/8ew343lf7pplgaovg6xyf/jota.png?rlkey=xkg2u68be0tahqwq69hfu2mbf [following]
# --2025-10-30 13:41:08--  https://www.dropbox.com/scl/fi/8ew343lf7pplgaovg6xyf/jota.png?rlkey=xkg2u68be0tahqwq69hfu2mbf
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc2ee6d1099a7448a6c9f3c86d82.dl.dropboxusercontent.com/cd/0/inline/C0MR15c5pB9hIxqg4Ns5JT0mzHG1Dm90-7BQKvtiw8mv5CUurNbkz4T9mygjL0h0OyoHuQR_q5UWdDmh_unxwDO_I0k0LEWVQK3DcnjHZFDixfDYcAXeA2CYjafkA5bw5yU/file# [following]
# --2025-10-30 13:41:09--  https://uc2ee6d1099a7448a6c9f3c86d82.dl.dropboxusercontent.com/cd/0/inline/C0MR15c5pB9hIxqg4Ns5JT0mzHG1Dm90-7BQKvtiw8mv5CUurNbkz4T9mygjL0h0OyoHuQR_q5UWdDmh_unxwDO_I0k0LEWVQK3DcnjHZFDixfDYcAXeA2CYjafkA5bw5yU/file
# Resolving uc2ee6d1099a7448a6c9f3c86d82.dl.dropboxusercontent.com (uc2ee6d1099a7448a6c9f3c86d82.dl.dropboxusercontent.com)... 162.125.4.15, 2620:100:601c:15::a27d:60f
# Connecting to uc2ee6d1099a7448a6c9f3c86d82.dl.dropboxusercontent.com (uc2ee6d1099a7448a6c9f3c86d82.dl.dropboxusercontent.com)|162.125.4.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 450 [image/png]
# Saving to: ‘jota.png’
#
# jota.png            100%[===================>]     450  --.-KB/s    in 0s
#
# 2025-10-30 13:41:09 (122 MB/s) - ‘jota.png’ saved [450/450]

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('jota.png',0)
plt.imshow(img,cmap='gray')
plt.title('original')
plt.show()

# %% [markdown]
# # Erosion

# %%
kernel = np.ones((5,5),np.uint8)
erosion = cv2.erode(img,kernel,iterations = 1)
plt.imshow(erosion,cmap='gray')
plt.title('erosion')
plt.show()

# %% [markdown]
# # Dilation

# %%
dilation = cv2.dilate(img,kernel,iterations = 1)
plt.imshow(dilation,cmap='gray')
plt.title('dilation')
plt.show()

# %% [markdown]
# # Opening

# %%
(N,M) = img.shape

img_noise = img.copy()

for i in range(N):
  for j in range(M):
    if np.random.rand()>0.99:
      img_noise[i,j] = 255

plt.imshow(img_noise,cmap='gray')
plt.title('original + noise (white)')
plt.show()

# %%
opening = cv2.morphologyEx(img_noise, cv2.MORPH_OPEN, kernel)
plt.imshow(opening,cmap='gray')
plt.title('open')
plt.show()

# %% [markdown]
# # Closing

# %%
(N,M) = img.shape

img_noise = img.copy()

for i in range(N):
  for j in range(M):
    if np.random.rand()>0.97:
      img_noise[i,j] = 0

plt.imshow(img_noise,cmap='gray')
plt.title('original with noise (black)')
plt.show()

# %%
closing = cv2.morphologyEx(img_noise, cv2.MORPH_CLOSE, kernel)
plt.imshow(closing,cmap='gray')
plt.title('close')
plt.show()

# %% [markdown]
# # Fill holes

# %%
def fillhole(input_image):
    '''
    input gray binary image  get the filled image by floodfill method
    Note: only holes surrounded in the connected regions will be filled.
    :param input_image:
    :return:
    from https://www.programcreek.com/python/example/89425/cv2.floodFill
    '''
    im_flood_fill = input_image.copy()
    h, w = input_image.shape[:2]
    mask = np.zeros((h + 2, w + 2), np.uint8)
    im_flood_fill = im_flood_fill.astype("uint8")
    cv2.floodFill(im_flood_fill, mask, (0, 0), 255)
    im_flood_fill_inv = cv2.bitwise_not(im_flood_fill)
    img_out = input_image | im_flood_fill_inv
    return img_out

# %%
im_fill = fillhole(img)

plt.imshow(im_fill,cmap='gray')
plt.title('fill holes')
plt.show()

# %% [markdown]
# # Skeletization
#
# By [N. Reddy](https://medium.com/analytics-vidhya/skeletonization-in-python-using-opencv-b7fa16867331)

# %%
# Step 1: Create an empty skeleton
size = np.size(img)
skel = np.zeros(img.shape, np.uint8)

# Get a Cross Shaped Kernel
element = cv2.getStructuringElement(cv2.MORPH_CROSS, (3,3))

# Repeat steps 2-4
while True:
    #Step 2: Open the image
    open = cv2.morphologyEx(img, cv2.MORPH_OPEN, element)
    #Step 3: Substract open from the original image
    temp = cv2.subtract(img, open)
    #Step 4: Erode the original image and refine the skeleton
    eroded = cv2.erode(img, element)
    skel = cv2.bitwise_or(skel,temp)
    img = eroded.copy()
    # Step 5: If there are no white pixels left ie.. the image has been completely eroded, quit the loop
    if cv2.countNonZero(img)==0:
        break

plt.imshow(skel,cmap='gray')
plt.title('skeletization')
plt.show()

# %% [markdown]
# # Morphological Gradient

# %%
gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
plt.imshow(gradient,cmap='gray')
plt.title('gradient')
plt.show()

# %% [markdown]
# # Morphological Operations in Grayscale Images

# %%
# !wget https://www.dropbox.com/s/ccebfv6fhlk6h4q/tazmania.png
# Out:
# --2025-10-30 13:41:13--  https://www.dropbox.com/s/ccebfv6fhlk6h4q/tazmania.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/7t2g5u3anb0wc0osntgia/tazmania.png?rlkey=ghojt8e1spg9rymljyps7fyg7 [following]
# --2025-10-30 13:41:13--  https://www.dropbox.com/scl/fi/7t2g5u3anb0wc0osntgia/tazmania.png?rlkey=ghojt8e1spg9rymljyps7fyg7
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf4cbe1670701426a46983f0040.dl.dropboxusercontent.com/cd/0/inline/C0NIia0DxtmMXN0BMyCw6I95plrFqkaxoknSqBli1cUifPG9lWve9BhQTN-hnlxXxdsh6TdNlzoJdTMdYfrCD1rFaCxhMzcCMFY8aukzyKTIis9p1iT9zaduwapenbPGr4s/file# [following]
# --2025-10-30 13:41:14--  https://ucf4cbe1670701426a46983f0040.dl.dropboxusercontent.com/cd/0/inline/C0NIia0DxtmMXN0BMyCw6I95plrFqkaxoknSqBli1cUifPG9lWve9BhQTN-hnlxXxdsh6TdNlzoJdTMdYfrCD1rFaCxhMzcCMFY8aukzyKTIis9p1iT9zaduwapenbPGr4s/file
# Resolving ucf4cbe1670701426a46983f0040.dl.dropboxusercontent.com (ucf4cbe1670701426a46983f0040.dl.dropboxusercontent.com)... 162.125.4.15, 2620:100:601c:15::a27d:60f
# Connecting to ucf4cbe1670701426a46983f0040.dl.dropboxusercontent.com (ucf4cbe1670701426a46983f0040.dl.dropboxusercontent.com)|162.125.4.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 975047 (952K) [image/png]
# Saving to: ‘tazmania.png’
#
# tazmania.png        100%[===================>] 952.19K  --.-KB/s    in 0.05s
#
# 2025-10-30 13:41:14 (18.7 MB/s) - ‘tazmania.png’ saved [975047/975047]

# %%
img = cv2.imread('tazmania.png',0)
plt.figure(figsize=(15,18))
plt.imshow(img,cmap='gray')
plt.title('original')
plt.show()

# %%
n = 7
kernel = np.ones((n,n),np.uint8)

# %%
erosion = cv2.erode(img,kernel,iterations = 1)
plt.figure(figsize=(15,18))
plt.imshow(erosion,cmap='gray')
plt.title('erosion')
plt.show()

# %%
dilation = cv2.dilate(img,kernel,iterations = 1)
plt.figure(figsize=(15,18))
plt.imshow(dilation,cmap='gray')
plt.title('dilation')
plt.show()

# %%
gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
plt.figure(figsize=(15,18))
#plt.imshow(gradient,cmap='gray')
plt.imshow(gradient) #color rerpesentation
plt.title('gradient')
plt.show()
